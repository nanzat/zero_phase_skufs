# %% [markdown]
# # Разведочный анализ цен на аренду квартир

# %% [markdown]
# ## Распределение цен по количеству комнат квартир

# %% [markdown]
# ### Всего кваритир: **23368**
# ### Квартиры расположены в Москве, Санкт-Петербурге и Краснодарском крае
# ### Больше всего двухкомнатных квартир

# %% [markdown]
# ## Распределение квартир по числу комнат

# %% [markdown]
# ## Распределение цен на аренду

# %%
# Out:
# [Text(0.5, 0, 'Аренда в млн.руб./месяц'), Text(0, 0.5, 'Частота')]

# %% [markdown]
# ### Цены находятся в диапазоне от **5 тысяч** до **3 миллионов** рублей
# ### Средняя цена за аренду: **83** тысячи рублей
# ### Наиболее частовстречающаяся цена: **40 тысяч рублей**
# ### Медиана цены **49,5** тысячи рублей

# %% [markdown]
# ## Распределение цен на аренду и площади квартир

# %% [markdown]
# ### Площади квартир находятся в диапазоне от **7** до **811** квадратных метров
# ### Средняя площадь: **63** квадратных метров
# ### Наиболее частовстречающаяся цена: **40** квадратных метра
# ### Медиана площади **48** квадратных метра
